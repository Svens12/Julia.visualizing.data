# %%
using Pkg

# %%
Pkg.add("Plots")

# %%
using Plots
# Out:
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# ┌ Warning: backend `GR` is not installed.
# └ @ Plots C:\Users\admin\.julia\packages\Plots\M4dfL\src\backends.jl:37
# [ Info: GR

# %%
plot()

# %%
x=1:15; y=rand(15);

# %%
plot(x,y)

# %%
z=rand(15);

# %%
plot!(x,z)

# %%
p=plot(x,y)
plot!(p,x,z)

# %%
plot(x,y,title="One random Line chart")

# %%
plot(x,y,title="One random Line chart",label="Line Chart 1")

# %%
plot(x,y,xlabel="X axis label", ylabel="Y axis Label")

# %%
scatter(x,y)

# %%
bar(x,y)

# %%
histogram(y)

# %%
p1=plot(x,y)
p2=scatter(x,y)
p3=bar(x,y)
p4=histogram(y)
plot(p1,p2,p3,p4,layout=(2,2), legend=false)

# %%
y=rand(15,4)
plot(x,y,layout=(4,1))
